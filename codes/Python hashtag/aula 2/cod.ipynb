# %%
import pandas as pd
tabela = pd.read_csv('cancelamentos.csv')
tabela = tabela.drop(columns='CustomerID')
display(tabela)
# Out:
#        idade    sexo  tempo_como_cliente  frequencia_uso  ligacoes_callcenter  \
# 0       23.0    Male                13.0            22.0                  2.0
# 1       49.0    Male                55.0            16.0                  3.0
# 2       30.0    Male                 7.0             1.0                  0.0
# 3       26.0    Male                40.0             5.0                  3.0
# 4       27.0  Female                17.0            30.0                  5.0
# ...      ...     ...                 ...             ...                  ...
# 49995   62.0  Female                35.0             7.0                  2.0
# 49996   36.0    Male                43.0            21.0                  2.0
# 49997   55.0    Male                42.0             8.0                  1.0
# 49998   40.0  Female                14.0            19.0                  1.0
# 49999   64.0    Male                41.0            29.0                  5.0
#
# ...

# %%
display(tabela.info())
tabela = tabela.dropna()
display(tabela.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   idade                   50000 non-null  float64
#  1   sexo                    49997 non-null  str
#  2   tempo_como_cliente      49998 non-null  float64
#  3   frequencia_uso          50000 non-null  float64
#  4   ligacoes_callcenter     50000 non-null  float64
#  5   dias_atraso             50000 non-null  float64
#  6   assinatura              50000 non-null  str
#  7   duracao_contrato        50000 non-null  str
#  8   total_gasto             50000 non-null  float64
#  9   meses_ultima_interacao  50000 non-null  float64
#  10  cancelou                50000 non-null  float64
# dtypes: float64(8), str(3)
# memory usage: 4.2 MB
# None
# <class 'pandas.DataFrame'>
# Index: 49996 entries, 0 to 49999
# Data columns (total 11 columns):
# ...

# %%
tabela['cancelou'].valeu_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2632\4239135465.py in ?()
# ----> 1 tabela['cancelou'].valeu_counts()
#
# c:\Users\LRGION\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'valeu_counts'

# %%
import plotly as px
grafico = px.histogram(tabela, x='cancelou' )
grafico.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 import plotly as px
# ----> 2 grafico = px.histogram(tabela, x='cancelou' )
#       3 grafico.show()
#
# File c:\Users\LRGION\AppData\Local\Programs\Python\Python314\Lib\site-packages\_plotly_utils\importers.py:39, in relative_import.<locals>.__getattr__(import_name)
#      36     class_module = importlib.import_module(rel_module, parent_name)
#      37     return getattr(class_module, class_name)
# ---> 39 raise AttributeError(
#      40     "module {__name__!r} has no attribute {name!r}".format(
#      41         name=import_name, __name__=parent_name
#      42     )
#      43 )
#
# AttributeError: module 'plotly' has no attribute 'histogram'
